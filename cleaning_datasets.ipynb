# %% [markdown]
# # Chargement des données et des modules

# %%
# Chargement des librairies
import pandas as pd
import numpy as np

# Affichage propre des graphiques
# %matplotlib inline

# %%
# Chargement des données
disasters = pd.read_csv("data/disasters_1900_2021.csv")
conflicts = pd.read_csv("data/conflicts.csv")
indicator_info = pd.read_csv("data/indicator_info.csv") # Ce dataset ne servira que d'un simple document supplémentaire pour comprendre les indicateurs dans le jeu de donnée Demographics
life_expectancy = pd.read_csv("data/demographic.csv", low_memory=False)
health_inequality = pd.read_excel("data/health_inequality.xlsx")

# %%
# Apercu du jeu de donnée Natural Disasters
disasters.head(5)
# Out:
#    Year   Seq Glide Disaster Group Disaster Subgroup      Disaster Type  \
# 0  1900  9002   NaN        Natural    Climatological            Drought
# 1  1900  9001   NaN        Natural    Climatological            Drought
# 2  1902    12   NaN        Natural       Geophysical         Earthquake
# 3  1902     3   NaN        Natural       Geophysical  Volcanic activity
# 4  1902    10   NaN        Natural       Geophysical  Volcanic activity
#
#   Disaster Subtype Disaster Subsubtype   Event Name     Country  ...  \
# 0          Drought                 NaN          NaN  Cabo Verde  ...
# 1          Drought                 NaN          NaN       India  ...
# 2  Ground movement                 NaN          NaN   Guatemala  ...
# 3         Ash fall                 NaN  Santa Maria   Guatemala  ...
# 4         Ash fall                 NaN  Santa Maria   Guatemala  ...
#
#   No Affected No Homeless Total Affected Insured Damages ('000 US$)  \
# ...

# %%
# Apercu du jeu de donnée Conflicts
conflicts.head(5)
# Out:
#    conflict_id       location               side_a side_a_id side_a_2nd  \
# 0        11342          India  Government of India       141        NaN
# 1        11342          India  Government of India       141        NaN
# 2        11343  Egypt, Israel  Government of Egypt       117        NaN
# 3        11343  Egypt, Israel  Government of Egypt       117        NaN
# 4        11343  Egypt, Israel  Government of Egypt       117        NaN
#
#                  side_b side_b_id side_b_2nd  incompatibility territory_name  \
# 0                  GNLA      1163        NaN                1       Garoland
# 1                  GNLA      1163        NaN                1       Garoland
# 2  Government of Israel       121        NaN                1     Suez/Sinai
# 3  Government of Israel       121        NaN                1     Suez/Sinai
# 4  Government of Israel       121        NaN                1     Suez/Sinai
#
# ...

# %%
# Apercu du jeu de donnée Info Supplémentaire
indicator_info.head(5)
# Out:
#    IndicatorNo       Topic               Indicator  \
# 0            1  Population         TPopulation1Jan
# 1            2  Population        TPopulation1July
# 2            3  Population    TPopulationMale1July
# 3            4  Population  TPopulationFemale1July
# 4            5  Population              PopDensity
#
#                        IndicatorName                   Unit
# 0  Total Population, as of 1 January              thousands
# 1     Total Population, as of 1 July              thousands
# 2      Male Population, as of 1 July              thousands
# 3    Female Population, as of 1 July              thousands
# 4   Population Density, as of 1 July  persons per square km

# %%
# Apercu du jeu de donnée Demographic
life_expectancy.head(5)
# Out:
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0        NaN   5507   NaN       NaN       NaN        NaN        NaN
# 1        NaN   5507   NaN       NaN       NaN        NaN        NaN
# 2        NaN   5507   NaN       NaN       NaN        NaN        NaN
# 3        NaN   5507   NaN       NaN       NaN        NaN        NaN
# 4        NaN   5507   NaN       NaN       NaN        NaN        NaN
#
#   LocTypeName  ParentID                           Location  ...  Q0060Male  \
# 0         NaN       NaN  ADB region: Central and West Asia  ...   654.5798
# 1         NaN       NaN  ADB region: Central and West Asia  ...   642.5944
# 2         NaN       NaN  ADB region: Central and West Asia  ...   630.8166
# 3         NaN       NaN  ADB region: Central and West Asia  ...   619.9937
# 4         NaN       NaN  ADB region: Central and West Asia  ...   610.3878
#
#   Q0060Female     Q1550  Q1550Male  Q1550Female     Q1560  Q1560Male  \
# ...

# %%
health_inequality.head(5)
# Out:
#        setting  date                         source  indicator_abbr  \
# 0  Afghanistan  1957  WHO Global Health Observatory  MDG_0000000001
# 1  Afghanistan  1957  WHO Global Health Observatory  MDG_0000000001
# 2  Afghanistan  1957  WHO Global Health Observatory  MDG_0000000007
# 3  Afghanistan  1957  WHO Global Health Observatory  MDG_0000000007
# 4  Afghanistan  1958  WHO Global Health Observatory  MDG_0000000001
#
#                                       indicator_name dimension subgroup  \
# 0  Infant mortality rate (deaths per 1000 live bi...       Sex   Female
# 1  Infant mortality rate (deaths per 1000 live bi...       Sex     Male
# 2  Under-five mortality rate (model-based estimat...       Sex   Female
# 3  Under-five mortality rate (model-based estimat...       Sex     Male
# 4  Infant mortality rate (deaths per 1000 live bi...       Sex   Female
#
#      estimate  se       ci_lb  ...  iso3  favourable_indicator  \
# ...

# %% [markdown]
# # Nettoyage des données

# %% [markdown]
# ## Pour le jeu de donnée "Natural Disasters"

# %% [markdown]
# ### Ajout des filtres pour les intervalles de dates

# %% [markdown]
# ### Sélection des colonnes utiles

# %%
disasters = disasters[['Year', 'Country', 'Disaster Type', 'Total Deaths', 'Total Affected']]

# %%
disasters.head(5)
# Out:
#    Year     Country      Disaster Type  Total Deaths  Total Affected
# 0  1900  Cabo Verde            Drought       11000.0             NaN
# 1  1900       India            Drought     1250000.0             NaN
# 2  1902   Guatemala         Earthquake        2000.0             NaN
# 3  1902   Guatemala  Volcanic activity        1000.0             NaN
# 4  1902   Guatemala  Volcanic activity        6000.0             NaN

# %% [markdown]
# ### Renommage des colonnes

# %%
# Afin d'enlever les espaces 
disasters = disasters.rename(columns={
    'Year': 'Year',
    'Country': 'Country',
    'Disaster Type': 'Disaster_type',
    'Total Deaths': 'Total_deaths',
    'Total Affected': 'Total_affected'
})

# %% [markdown]
# ### Filtrage de 1950-2021

# %%
disasters = disasters[disasters['Year'].between(1950,2021)]

# %% [markdown]
# ### Gestion des valeurs manquantes

# %% [markdown]
# La valeur manquante dans le jeu de donnée peut autant signifier qu'il n'y a **pas eu de morts** dans le cas de la colonne **Total Deaths** ou que la donnée soit vraiment **manquante**.

# %%
# Regardons le nombre de valeurs manquantes de la colonne Total Deaths par type de catastrophe naturelle
print(disasters.groupby('Disaster_type')['Total_deaths'].apply(
    lambda x: x.isnull().sum()
).sort_values(ascending=False))
# Out:
# Disaster_type
# Flood                    1507
# Storm                    1156
# Drought                   679
# Earthquake                366
# Wildfire                  270
# Epidemic                  228
# Volcanic activity         171
# Extreme temperature       113
# Insect infestation         93
# Landslide                  35
# Mass movement (dry)         2
# Impact                      1
# Animal accident             0
# Fog                         0
# Glacial lake outburst       0
# Name: Total_deaths, dtype: int64

# %% [markdown]
# On remarque que les valeurs manquantes sont concentrées sur les 3 catastrophes naturelles: **inondation, tempête, sécheresse**. Ce qui est logique étant donné que ce sont les catastrophes naturelles **les moins mortelles** pour la population. Donc, les valeurs manquantes ici représentent réellement une donnée. Pour les comptabiliser, on va les remplacer par 0.

# %%
# Remplir les valeurs manquantes par 0
disasters['Total_deaths'] = disasters['Total_deaths'].fillna(0)
disasters['Total_affected'] = disasters['Total_affected'].fillna(0)

# Imputation par la médiane par type de catastrophe
columns = ['Total_deaths', 'Total_affected']

for col in columns:
    disasters[col] = disasters.groupby('Country')[col].transform(
        lambda x: x.fillna(x.median())
    )
    disasters[col] = disasters[col].fillna(disasters[col].median())

# %%
# Aggrégation par année et par pays
disasters_agg = disasters.groupby(['Country', 'Year']).agg(
    nb_disasters     = ('Disaster_type', 'count'),
    total_deaths_per_country = ('Total_deaths', 'sum'),
    total_affected   = ('Total_affected', 'sum')
).reset_index()

# %%
disasters_agg.head(5)
# Out:
#        Country  Year  nb_disasters  total_deaths_per_country  total_affected
# 0  Afghanistan  1954             1                    2000.0             0.0
# 1  Afghanistan  1956             2                     151.0          2000.0
# 2  Afghanistan  1963             1                     107.0             0.0
# 3  Afghanistan  1969             1                       0.0         48000.0
# 4  Afghanistan  1971             2                     100.0             0.0

# %% [markdown]
# ## Pour le jeux de donnée "Conflicts"

# %% [markdown]
# ### Renommage des colonnes

# %% [markdown]
# 1 = Conflit mineur : entre 25 et 999 morts au combat au cours d'une année donnée. 2 = Guerre : au moins 1 000 morts au combat au cours d'une année donnée.

# %% [markdown]
# 1 = extrasystémique (entre un État et un groupe non étatique situé hors de son propre territoire, où la partie gouvernementale lutte pour conserver le contrôle d'un territoire situé en dehors du système étatique) 2 = interétatique (les deux parties sont des États dans le système de classification de Gleditsch et Ward) 3 = intra-étatique (la partie A est toujours un gouvernement ; la partie B est toujours un ou plusieurs groupes rebelles ; il n'y a pas d'implication de gouvernements étrangers avec des troupes, c'est-à-dire qu'il n'y a pas de code side_a_2nd ou side_b_2nd) 4 = intra-étatique internationalisé (le camp A est toujours un gouvernement ; le camp B est toujours un ou plusieurs groupes rebelles ; il y a implication de gouvernements étrangers avec des troupes, c'est-à-dire qu'il y a au moins UN code side_a_2nd ou side_b_2nd)

# %%
conflicts = conflicts.rename(columns={
    'year' : 'year',
    'location': 'Country'
})

# %% [markdown]
# ### Filtrage pour l'année 1950 jusqu'à 2021

# %%
conflicts =conflicts[conflicts['year'].between(1950, 2021)]

# %% [markdown]
# ### Sélection des colonnes essentielles

# %%
conflicts =conflicts[['Country', 'year', 'intensity_level', 'type_of_conflict']]

# %%
conflicts.head(5)
# Out:
#          Country  year  intensity_level  type_of_conflict
# 0          India  2012                1                 3
# 1          India  2014                1                 3
# 2  Egypt, Israel  1967                2                 2
# 3  Egypt, Israel  1969                1                 2
# 4  Egypt, Israel  1970                1                 2

# %% [markdown]
# ## Pour le jeu de donnée "Demographics"

# %% [markdown]
# ### Sélection des colonnes nécessaires

# %%
life_expectancy = life_expectancy[['Location', 'Time', 'LEx', 'LExMale', 'LExFemale', 'Deaths','DeathsMale', 'DeathsFemale', 'IMR', 'PopGrowthRate', 'InfantDeaths', 'Under5Deaths']]

# %% [markdown]
# ### Renommage des colonnes

# %%
life_expectancy = life_expectancy.rename(columns={
    'Location': 'Country',
    'Time': 'Year',
    'LEx': 'Life_expectancy',
    'LExMale': 'Life_expectancy_male',
    'LExFemale': 'Life_expectancy_female',
    'IMR': 'Infant_mortality_rate'
})

# %% [markdown]
# ### Filtrage des années

# %%
life_expectancy = life_expectancy[life_expectancy['Year'].between(1950,2021)]

# %%
life_expectancy.head(5)
# Out:
#                              Country  Year  Life_expectancy  \
# 0  ADB region: Central and West Asia  1950          38.6085
# 1  ADB region: Central and West Asia  1951          39.6435
# 2  ADB region: Central and West Asia  1952          40.5673
# 3  ADB region: Central and West Asia  1953          41.4405
# 4  ADB region: Central and West Asia  1954          42.2044
#
#    Life_expectancy_male  Life_expectancy_female    Deaths  DeathsMale  \
# 0               38.1082                 39.1261  1710.506     896.754
# 1               39.1333                 40.1776  1693.605     888.959
# 2               40.0791                 41.0807  1685.112     884.170
# 3               40.9378                 41.9706  1679.966     882.165
# 4               41.7062                 42.7313  1680.927     882.632
#
#    DeathsFemale  Infant_mortality_rate  PopGrowthRate  InfantDeaths  \
# 0       813.752               207.0834          2.058       600.102
# ...

# %% [markdown]
# ## Pour le jeu de donnée "Health Inequality"

# %% [markdown]
# ### Filtrage pour l'année 1950 jusqu'à 2021

# %%
health_inequality.tail(5)
# Out:
#                                setting  date                         source  \
# 917758  occupied Palestinian territory  2023  WHO Global Health Observatory
# 917759  occupied Palestinian territory  2024  WHO Global Health Observatory
# 917760  occupied Palestinian territory  2024  WHO Global Health Observatory
# 917761  occupied Palestinian territory  2024  WHO Global Health Observatory
# 917762  occupied Palestinian territory  2024  WHO Global Health Observatory
#
#            indicator_abbr                                     indicator_name  \
# 917758    NUTSTUNTINGPREV  Stunting prevalence among children aged <5 yea...
# 917759  NUTOVERWEIGHTPREV  Overweight prevalence among children aged <5 y...
# 917760  NUTOVERWEIGHTPREV  Overweight prevalence among children aged <5 y...
# 917761    NUTSTUNTINGPREV  Stunting prevalence among children aged <5 yea...
# 917762    NUTSTUNTINGPREV  Stunting prevalence among children aged <5 yea...
#
# ...

# %%
health_inequality = health_inequality[health_inequality['date'].between(1950,2021)]

# %%
health_inequality.tail(5)
# Out:
#                                setting  date                         source  \
# 917662  occupied Palestinian territory  2021  WHO Global Health Observatory
# 917663  occupied Palestinian territory  2021  WHO Global Health Observatory
# 917664  occupied Palestinian territory  2021  WHO Global Health Observatory
# 917665  occupied Palestinian territory  2021  WHO Global Health Observatory
# 917666  occupied Palestinian territory  2021  WHO Global Health Observatory
#
#                        indicator_abbr  \
# 917662  WSH_SANITATION_SAFELY_MANAGED
# 917663                WSH_WATER_BASIC
# 917664                WSH_WATER_BASIC
# 917665       WSH_WATER_SAFELY_MANAGED
# 917666       WSH_WATER_SAFELY_MANAGED
#
#                                            indicator_name           dimension  \
# 917662  Population using safely managed sanitation ser...  Place of residence
# 917663  Population using at least basic drinking-water...  Place of residence
# ...

# %% [markdown]
# Les dates ont bien été filtrées.

# %% [markdown]
# ### Sélection des colonnes nécessaires

# %%
print(health_inequality.columns)
# Out:
# Index(['setting', 'date', 'source', 'indicator_abbr', 'indicator_name',
#        'dimension', 'subgroup', 'estimate', 'se', 'ci_lb', 'ci_ub',
#        'population', 'flag', 'setting_average', 'iso3', 'favourable_indicator',
#        'indicator_scale', 'ordered_dimension', 'subgroup_order',
#        'reference_subgroup', 'whoreg6', 'wbincome2025', 'update',
#        'dataset_id'],
#       dtype='str')

# %% [markdown]
# Toutes les colonnes semblent nécessaires, aucune séléction ne sera faites pour ce dataset.

# %% [markdown]
# ### Visionnage des catégories dans les colonnes

# %%
print("setting :")
print(health_inequality["setting"].unique())
print("\n")

print("indicator_name :")
print(health_inequality["indicator_name"].unique())
print("\n")

print("subgroup :")
print(health_inequality["subgroup"].unique())
print("\n")

print("whoreg6 :")
print(health_inequality["whoreg6"].unique())
# Out:
# setting :
# <StringArray>
# [                       'Afghanistan',                            'Albania',
#                             'Algeria',                            'Andorra',
#                              'Angola',                'Antigua and Barbuda',
#                           'Argentina',                            'Armenia',
#                           'Australia',                            'Austria',
#  ...
#            'United States of America',                            'Uruguay',
#                          'Uzbekistan',                            'Vanuatu',
#  'Venezuela (Bolivarian Republic of)',                           'Viet Nam',
#                               'Yemen',                             'Zambia',
#                            'Zimbabwe',     'occupied Palestinian territory']
# Length: 198, dtype: str
#
#
# indicator_name :
# <StringArray>
# ...

# %% [markdown]
# ### Renommage des colonnes

# %%
health_inequality = health_inequality.rename(columns={
    "setting": "country",
    "date": "date",
    "indicator_abbr": "indicator_abbr",
    "indicator_name": "indicator_name",
    "subgroup": "group",
    "estimate": "value",
    "iso3": "country_code",
    "whoreg6": "region",
    "wbincome2025": "income_level",
    "ci_lb": "ci_lower",
    "ci_ub": "ci_upper",
})

# %%
health_inequality.head(5)
# Out:
#        country country_code                 region income_level  date  \
# 0  Afghanistan          AFG  Eastern Mediterranean   Low-income  1957
# 1  Afghanistan          AFG  Eastern Mediterranean   Low-income  1957
# 2  Afghanistan          AFG  Eastern Mediterranean   Low-income  1957
# 3  Afghanistan          AFG  Eastern Mediterranean   Low-income  1957
# 4  Afghanistan          AFG  Eastern Mediterranean   Low-income  1958
#
#             update dataset_id  indicator_abbr  \
# 0  17 October 2025    rep_gho  MDG_0000000001
# 1  17 October 2025    rep_gho  MDG_0000000001
# 2  17 October 2025    rep_gho  MDG_0000000007
# 3  17 October 2025    rep_gho  MDG_0000000007
# 4  17 October 2025    rep_gho  MDG_0000000001
#
#                                       indicator_name  indicator_scale  \
# 0  Infant mortality rate (deaths per 1000 live bi...             1000
# 1  Infant mortality rate (deaths per 1000 live bi...             1000
# ...

# %% [markdown]
# ## Fractionnement ou fusion des colonnes

# %% [markdown]
# ### Fractionnement de la colonnes "indicator_name"

# %% [markdown]
# Afin de faciliter le futur traitement des données, la grille de lecture de dataset se doit d'être la plus lisible possible, ce qui facilitera le maniement des données.
# Evidemment, lorsqu'on fait des simplifications, il est plus prudent de créer des colonnes supplémentaires que d'écraser les anciennes (plus riches d'information).
#
# Comme nous l'avons vu dans la catégorie "Visionnage des colonnes", le dataset est très complet. Il couvre nos besoins et plus encore.
#
# Nous avons bien trop de catégories pour les thèmes suivants :
# - l'âge
# - le cholesterole
# - et enfin, la distance pour obtenir une aide technique (assistive techology)

# %% [markdown]
# ### Simplification de l'âge

# %% [markdown]
# Voici les catégories d'âge disponsible :
# - 10-19 years,
# - 5-9 years,
# - 10-14 years,
# - 15-19 years,
# - 15-24 years,
# - 25-34 years,
# - 35-44 years,
# - 45-54 years,
# - 55-64 years,
# - 65-74 years,
# - 75-84 years,
# - 85+ years,
# - 0-4 years,
# - 18-29 years,
# - 30-39 years,
# - 40-49 years,
# - 5-17 years,
# - 50-59 years,
# - 60-69 years,
# - 70-79 years,
# - et enfin 80+ years.
#
# Nous allons les simplifier en 3 catégories principales :
# - les -25 ans
# - les -60 ans
# - et les +60 ans

# %%
def age_group(x):
    if pd.isna(x):
        return np.nan

    if x in [
        "0-4 years",
        "5-9 years",
        "10-14 years",
        "5-17 years",
        "15-19 years",
        "10-19 years",
        "15-19 years",
        "15-24 years"
    ]:
        return "-25"

    elif x in [
        "18-29 years",
        "25-34 years",
        "30-39 years",
        "35-44 years",
        "45-54 years",
        "50-59 years"
    ]:
        return "-60"

    elif x in [
        "55-64 years",
        "60-69 years",
        "65-74 years",
        "70-79 years",
        "75-84 years",
        "80+ years",
        "85+ years",
        "Only older adults (>=60 years)"
    ]:
        return "60+"

    return np.nan

health_inequality["age"] = health_inequality["group"].apply(age_group)

# %%
health_inequality.iloc[376:381] # choix de ligne qui présente la catégorie "cholesterole" afin de vérifier si tout fonctionne
# Out:
#          country country_code                 region income_level  date  \
# 376  Afghanistan          AFG  Eastern Mediterranean   Low-income  1991
# 377  Afghanistan          AFG  Eastern Mediterranean   Low-income  1991
# 378  Afghanistan          AFG  Eastern Mediterranean   Low-income  1991
# 379  Afghanistan          AFG  Eastern Mediterranean   Low-income  1991
# 380  Afghanistan          AFG  Eastern Mediterranean   Low-income  1991
#
#               update dataset_id          indicator_abbr  \
# 376  17 October 2025    rep_gho  NCD_BMI_PLUS2C_SEX_MLE
# 377  17 October 2025    rep_gho  NCD_BMI_PLUS2C_SEX_MLE
# 378  17 October 2025    rep_gho      NCD_CHOL_MEANHDL_A
# 379  17 October 2025    rep_gho      NCD_CHOL_MEANHDL_A
# 380  17 October 2025    rep_gho      NCD_CHOL_MEANHDL_C
#
#                                         indicator_name  indicator_scale  \
# 376  Obesity prevalence among school-age children a...              100
# ...

# %% [markdown]
# Si on regarde la dernière colonne, on voit bien que l'âge a été ajouté (de manière simplifiée)

# %% [markdown]
# ### Simplification des données sur le cholesterole

# %% [markdown]
# Voici les données disponibles sur le cholestérole :
# - Cholesterol, mean high-density lipoprotein (HDL) (age-standardized),
# - Cholesterol, mean high-density lipoprotein (HDL) (crude),
# - Cholesterol, mean non-high-density lipoprotein (non-HDL) (age-standardized),
# - Cholesterol, mean non-high-density lipoprotein (non-HDL) (crude),
# - Cholesterol, mean total (age-standardized),
# et enfi, Cholesterol, mean total (crude).
#
# Ici nous avons fait le choix de garder uniquement les mesures standardisées en fonction de l'âge et du pays.
# Ce sont les mesures les plus fiables à utiliser lors de comparaison internationales.
#
# On va donc garder :
# - Cholesterol, mean high-density lipoprotein (HDL) (age-standardized),
# - Cholesterol, mean non-high-density lipoprotein (non-HDL) (age-standardized),
# - et Cholesterol, mean total (age-standardized)
#
# Qui seront respectivement renommé :
# - good
# - bad
# - total

# %%
def cholesterol_simplification(x):
    if pd.isna(x):
        return np.nan

    if x in ["Cholesterol, mean high-density lipoprotein (HDL) (age-standardized)"]:
        return "good"
    
    if x in ["Cholesterol, mean non-high-density lipoprotein (non-HDL) (age-standardized)"]:
        return "bad"
    
    if x in ["Cholesterol, mean total (age-standardized)"]:
        return "total"
    
health_inequality["cholesterol"] = health_inequality["indicator_name"].apply(cholesterol_simplification)

# %% [markdown]
# Vérifions tout de même que nous avons assez de données :

# %%
health_inequality["cholesterol"].value_counts()
# Out:
# cholesterol
# good     14898
# bad      14898
# total    14898
# Name: count, dtype: int64

# %%
health_inequality.iloc[1206:1217] # choix de ligne qui présente la catégorie "cholesterol" afin de vérifier si tout fonctionne
# Out:
#           country country_code                 region income_level  date  \
# 1206  Afghanistan          AFG  Eastern Mediterranean   Low-income  2000
# 1207  Afghanistan          AFG  Eastern Mediterranean   Low-income  2000
# 1208  Afghanistan          AFG  Eastern Mediterranean   Low-income  2000
# 1209  Afghanistan          AFG  Eastern Mediterranean   Low-income  2000
# 1210  Afghanistan          AFG  Eastern Mediterranean   Low-income  2000
# 1211  Afghanistan          AFG  Eastern Mediterranean   Low-income  2000
# 1212  Afghanistan          AFG  Eastern Mediterranean   Low-income  2000
# 1213  Afghanistan          AFG  Eastern Mediterranean   Low-income  2000
# 1214  Afghanistan          AFG  Eastern Mediterranean   Low-income  2000
# 1215  Afghanistan          AFG  Eastern Mediterranean   Low-income  2000
# 1216  Afghanistan          AFG  Eastern Mediterranean   Low-income  2000
#
#                update dataset_id                     indicator_abbr  \
# ...

# %% [markdown]
# Désormais, attaquons nous à la simplification de la distance pour obtenir une aide technique (assistive techology)

# %% [markdown]
# ### Simplification des annotations de la distance pour obtenir une aide technique (assistive techology)

# %% [markdown]
# Pour "assistive technology", nous avons les catégories suivantes :
# - Assistive technology: Travel distance to obtain assistive products (%) - 100+ km,
# - Assistive technology: Travel distance to obtain assistive products (%) - 26-50 km,
# - Assistive technology: Travel distance to obtain assistive products (%) - 51-100 km,
# - Assistive technology: Travel distance to obtain assistive products (%) - 6-25 km,
# - Assistive technology: Travel distance to obtain assistive products (%) - <6 km,
# - Assistive technology: Met need of assistive products (%),
# - Assistive technology: Need of assistive products (%),
# - et enfin, Assistive technology: Use of assistive products (%)
#
# Nous allons le renommer par les 6 catégories suivantes :
# - near
# - close
# - mid_distance
# - need
# - use
# - et enfin, coverage

# %%
def assistive_techno(x):
    if pd.isna(x):
        return np.nan
    
    if x in ["Assistive technology: Travel distance to obtain assistive products (%) - 100+ km",
             "Assistive technology: Travel distance to obtain assistive products (%) - 51-100 km"
            ]:
        return "near"
    
    if x in ["Assistive technology: Travel distance to obtain assistive products (%) - 26-50 km"]:
        return "mid_distance"
    
    if x in ["Assistive technology: Travel distance to obtain assistive products (%) - <6 km",
             "Assistive technology: Travel distance to obtain assistive products (%) - 6-25 km"]:
        return "close"

    if "Assistive technology: Need of assistive products (%)" in x:
        return "need"

    if "Assistive technology: Use of assistive products (%)" in x:
        return "use"

    if "Assistive technology: Met need of assistive products (%)" in x:
        return "met_need"
    
health_inequality["assistive_techno"] = health_inequality["indicator_name"].apply(assistive_techno)

# %%
health_inequality.iloc[599000:599010] # choix de ligne qui présente la catégorie "assitive technology" afin de vérifier si tout fonctionne
# Out:
#          country country_code                 region         income_level  \
# 613464  Pakistan          PAK  Eastern Mediterranean  Lower-middle-income
# 613465  Pakistan          PAK  Eastern Mediterranean  Lower-middle-income
# 613466  Pakistan          PAK  Eastern Mediterranean  Lower-middle-income
# 613467  Pakistan          PAK  Eastern Mediterranean  Lower-middle-income
# 613468  Pakistan          PAK  Eastern Mediterranean  Lower-middle-income
# 613469  Pakistan          PAK  Eastern Mediterranean  Lower-middle-income
# 613470  Pakistan          PAK  Eastern Mediterranean  Lower-middle-income
# 613471  Pakistan          PAK  Eastern Mediterranean  Lower-middle-income
# 613472  Pakistan          PAK  Eastern Mediterranean  Lower-middle-income
# 613473  Pakistan          PAK  Eastern Mediterranean  Lower-middle-income
#
#         date           update dataset_id           indicator_abbr  \
# 613464  2019  17 October 2025    rep_gho    ASSISTIVETECH_METNEED
# ...

# %% [markdown]
# ### Simplification des catégories sur le diabète

# %%
health_inequality.loc[
    health_inequality["indicator_name"].str.contains("Diabetes", na=False),
    "indicator_name"
].unique()
# Out:
# <StringArray>
# [        'Diabetes prevalence (18+ years) (age-standardized) (%)',
#          'Diabetes prevalence (30+ years) (age-standardized) (%)',
#                     'Diabetes prevalence (18+ years) (crude) (%)',
#                     'Diabetes prevalence (30+ years) (crude) (%)',
#  'Diabetes treatment coverage (30+ years) (age-standardized) (%)',
#             'Diabetes treatment coverage (30+ years) (crude) (%)']
# Length: 6, dtype: str

# %%
def diabetes_simplification(x):
    if pd.isna(x):
        return np.nan

    x = x.lower()

    if "prevalence" in x:
        return "prevalence"

    if "treatment coverage" in x:
        return "treatment_coverage"

    return np.nan

health_inequality["diabetes"] = health_inequality["indicator_name"].apply(diabetes_simplification)

# %%
health_inequality[health_inequality["indicator_name"].str.contains("Diabetes", na=False)]
# Out:
#                                country country_code                 region  \
# 300                        Afghanistan          AFG  Eastern Mediterranean
# 301                        Afghanistan          AFG  Eastern Mediterranean
# 302                        Afghanistan          AFG  Eastern Mediterranean
# 303                        Afghanistan          AFG  Eastern Mediterranean
# 304                        Afghanistan          AFG  Eastern Mediterranean
# ...                                ...          ...                    ...
# 917622  occupied Palestinian territory          PSE  Eastern Mediterranean
# 917623  occupied Palestinian territory          PSE  Eastern Mediterranean
# 917624  occupied Palestinian territory          PSE  Eastern Mediterranean
# 917625  occupied Palestinian territory          PSE  Eastern Mediterranean
# 917626  occupied Palestinian territory          PSE  Eastern Mediterranean
#
#                income_level  date           update dataset_id  \
# ...

# %% [markdown]
# ### Simplification des catégories sur l'hypertension

# %%
health_inequality.loc[
    health_inequality["indicator_name"].str.contains("Hypertension", na=False),
    "indicator_name"
].unique()
# Out:
# <StringArray>
# [                   'Hypertension: raised blood pressure (SBP>=140 OR DBP>=90) among adults aged 30-79 (crude) (%)',
#          'Hypertension: raised blood pressure (SBP>=140 OR DBP>=90) among adults aged 30-79 (age-standardized) (%)',
#  'Hypertension effective treatment coverage among adults aged 30-79 years with hypertension (age-standardized) (%)',
#             'Hypertension effective treatment coverage among adults aged 30-79 years with hypertension (crude) (%)',
#                  'Hypertension diagnosis coverage among adults aged 30-79 with hypertension (age-standardized) (%)',
#                             'Hypertension diagnosis coverage among adults aged 30-79 with hypertension (crude) (%)',
#                                      'Hypertension prevalence among adults aged 30-79 years (age-standardized) (%)',
#                                                 'Hypertension prevalence among adults aged 30-79 years (crude) (%)',
# ...

# %%
def hypertension_simplification(x):
    if pd.isna(x):
        return np.nan

    x = x.lower()

    if "prevalence" in x:
        return "prevalence"
    
    if "diagnosis coverage" in x:
        return "diagnosis"

    if "treatment coverage" in x and "effective" not in x:
        return "treatment"

    if "effective treatment" in x:
        return "effective_treatment"

    return np.nan
health_inequality["hypertension"] = health_inequality["indicator_name"].apply(hypertension_simplification)

# %%
health_inequality[health_inequality["indicator_name"].str.contains("Hypertension", na=False)]
# Out:
#                                country country_code                 region  \
# 252                        Afghanistan          AFG  Eastern Mediterranean
# 253                        Afghanistan          AFG  Eastern Mediterranean
# 254                        Afghanistan          AFG  Eastern Mediterranean
# 255                        Afghanistan          AFG  Eastern Mediterranean
# 312                        Afghanistan          AFG  Eastern Mediterranean
# ...                                ...          ...                    ...
# 917444  occupied Palestinian territory          PSE  Eastern Mediterranean
# 917445  occupied Palestinian territory          PSE  Eastern Mediterranean
# 917446  occupied Palestinian territory          PSE  Eastern Mediterranean
# 917447  occupied Palestinian territory          PSE  Eastern Mediterranean
# 917448  occupied Palestinian territory          PSE  Eastern Mediterranean
#
#                income_level  date           update dataset_id  \
# ...

# %% [markdown]
# ### Simplification des catégories sur l'alcoolémie

# %% [markdown]
# Listons toutes les catégories existantes :

# %%
health_inequality.loc[
    health_inequality["indicator_name"].str.contains("Alcohol", na=False),
    "indicator_name"
].unique()
# Out:
# <StringArray>
# [            'Alcohol, per capita consumption (15+ years, among drinkers only) (in litres of pure alcohol)',
#                                                                          'Alcohol, abstainers lifetime (%)',
#                                                                 'Alcohol, abstainers in past 12 months (%)',
#                                               'Alcohol, consumers in past 12 months (age-standardized) (%)',
#                                                                              'Alcohol, former drinkers (%)',
#  'Alcohol, heavy episodic drinking in past 30 days (15+ years, among drinkers only) (age-standardized) (%)',
#                       'Alcohol, heavy episodic drinking in past 30 days (15+ years) (age-standardized) (%)',
#                                                      'Alcohol, average daily intake among drinkers (grams)',
# ...

# %%
def alcohol_simplification(x):
    if pd.isna(x):
        return np.nan

    x = x.lower()

    if "abstainers" in x or "non-drinker" in x:
        return "no_or_light"

    if "consumers" in x or "average daily intake" in x:
        return "moderate"

    if "heavy episodic" in x or "heavy continuous" in x:
        return "heavy"

    if "harmful" in x or "attributable" in x or "cirrhosis" in x or "road traffic" in x or "dalys" in x:
        return "alcoholism"

    return np.nan

health_inequality["alcohol"] = health_inequality["indicator_name"].apply(alcohol_simplification)

# %%
health_inequality[health_inequality["indicator_name"].str.contains("Alcohol", na=False)]
# Out:
#             country country_code                 region         income_level  \
# 1270    Afghanistan          AFG  Eastern Mediterranean           Low-income
# 1271    Afghanistan          AFG  Eastern Mediterranean           Low-income
# 1272    Afghanistan          AFG  Eastern Mediterranean           Low-income
# 1273    Afghanistan          AFG  Eastern Mediterranean           Low-income
# 1274    Afghanistan          AFG  Eastern Mediterranean           Low-income
# ...             ...          ...                    ...                  ...
# 914169     Zimbabwe          ZWE                African  Lower-middle-income
# 914170     Zimbabwe          ZWE                African  Lower-middle-income
# 914171     Zimbabwe          ZWE                African  Lower-middle-income
# 914172     Zimbabwe          ZWE                African  Lower-middle-income
# 914173     Zimbabwe          ZWE                African  Lower-middle-income
#
# ...

# %% [markdown]
# ### Simplification des catégories sur le tabaggisme

# %% [markdown]
# Listons toutes les catégories existantes :

# %%
health_inequality.loc[
    health_inequality["indicator_name"].str.contains("Tobacco", na=False),
    "indicator_name"
].unique()
# Out:
# <StringArray>
# [                  'Tobacco: current cigarette smoking prevalence (model-based estimates) (%)',
#  'Tobacco, current cigarette smoking prevalence (model-based estimates, age-standardized) (%)',
#                      'Tobacco, current tobacco smoking prevalence (model-based estimates) (%)',
#    'Tobacco, current tobacco smoking prevalence (model-based estimates, age-standardized) (%)',
#                          'Tobacco, current tobacco use prevalence (model-based estimates) (%)',
#        'Tobacco, current tobacco use prevalence (model-based estimates, age-standardized) (%)',
#            'Tobacco: current cigarette smoking among adolescents (survey-based estimates) (%)',
#              'Tobacco, current e-cigarette use among adolescents (survey-based estimates) (%)',
#        'Tobacco, current smokeless tobacco use among adolescents (survey-based estimates) (%)',
#              'Tobacco, current tobacco smoking among adolescents (survey-based estimates) (%)',
# ...

# %%
def tobacco_simplification(x):
    if pd.isna(x):
        return np.nan

    x = x.lower()

    if "current tobacco use" in x and "daily" not in x and "smoking" not in x:
        return "non_smoker"

    if "current cigarette smoking" in x or "current smoking" in x:
        return "light_smoker"

    if "daily cigarette" in x or "daily tobacco smoking" in x:
        return "moderate_smoker"

    if "heavy" in x:
        return "heavy_smoker"

    return np.nan

health_inequality["tobacco"] = health_inequality["indicator_name"].apply(tobacco_simplification)

# %%
health_inequality[health_inequality["indicator_name"].str.contains("Tobacco", na=False)]
# Out:
#                                country country_code                 region  \
# 1162                       Afghanistan          AFG  Eastern Mediterranean
# 1163                       Afghanistan          AFG  Eastern Mediterranean
# 1164                       Afghanistan          AFG  Eastern Mediterranean
# 1165                       Afghanistan          AFG  Eastern Mediterranean
# 1166                       Afghanistan          AFG  Eastern Mediterranean
# ...                                ...          ...                    ...
# 917152  occupied Palestinian territory          PSE  Eastern Mediterranean
# 917153  occupied Palestinian territory          PSE  Eastern Mediterranean
# 917154  occupied Palestinian territory          PSE  Eastern Mediterranean
# 917155  occupied Palestinian territory          PSE  Eastern Mediterranean
# 917156  occupied Palestinian territory          PSE  Eastern Mediterranean
#
#                income_level  date           update dataset_id  \
# ...

# %% [markdown]
# ### Réordonner les colonnes

# %%
print(health_inequality.columns)
# Out:
# Index(['country', 'country_code', 'region', 'income_level', 'date', 'update',
#        'dataset_id', 'indicator_abbr', 'indicator_name', 'indicator_scale',
#        'favourable_indicator', 'source', 'dimension', 'group',
#        'subgroup_order', 'reference_subgroup', 'ordered_dimension',
#        'population', 'age', 'cholesterol', 'assistive_techno', 'value', 'se',
#        'ci_lower', 'ci_upper', 'setting_average', 'flag', 'diabetes',
#        'hypertension', 'alcohol', 'tobacco'],
#       dtype='str')

# %%
health_inequality = health_inequality[[

    # lieux
    "country", "country_code", "region", "income_level",
    "date", "update", "dataset_id",

    # Indicateurs
    "indicator_abbr", "indicator_name", "indicator_scale",
    "favourable_indicator", "source",

    # Regroupements / catégories
    "dimension", "group", "subgroup_order", "reference_subgroup",
    "ordered_dimension", "population", "age",

    # Nouveaux "features"   "alcohol", "tobacco", "diabetes", "hypertension",
    "cholesterol", "assistive_techno", "diabetes", "hypertension", "alcohol", "tobacco",

    # Valeurs
    "value", "se", "ci_lower", "ci_upper",
    "setting_average", "flag"
]]

# %%
pd.set_option("display.max_columns", None)
health_inequality.head(5)
# Out:
#        country country_code                 region income_level  date  \
# 0  Afghanistan          AFG  Eastern Mediterranean   Low-income  1957
# 1  Afghanistan          AFG  Eastern Mediterranean   Low-income  1957
# 2  Afghanistan          AFG  Eastern Mediterranean   Low-income  1957
# 3  Afghanistan          AFG  Eastern Mediterranean   Low-income  1957
# 4  Afghanistan          AFG  Eastern Mediterranean   Low-income  1958
#
#             update dataset_id  indicator_abbr  \
# 0  17 October 2025    rep_gho  MDG_0000000001
# 1  17 October 2025    rep_gho  MDG_0000000001
# 2  17 October 2025    rep_gho  MDG_0000000007
# 3  17 October 2025    rep_gho  MDG_0000000007
# 4  17 October 2025    rep_gho  MDG_0000000001
#
#                                       indicator_name  indicator_scale  \
# 0  Infant mortality rate (deaths per 1000 live bi...             1000
# 1  Infant mortality rate (deaths per 1000 live bi...             1000
# ...

# %%
health_inequality.to_csv("data/health_inequality.csv", index=False)
